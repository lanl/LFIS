# %%
import os

import numpy as np
import torch

import matplotlib.pyplot as plt


from LFIS.config.config import get_configuration, get_baseconfig
from LFIS.LF.LF import LF_base

from LFIS.util.util import (
                    run_stat,
                    save_file,
                    load_file)

torch.set_default_dtype(torch.float32)

# %%
def check_parameter(config):
    print(f'Case: {config.case}')
    print(f'Problem: {config.problemtype}')
    print(f'Number of steps: {config.nstep}')
    print(f'Device: {config.device}')
    print(f'Number of dimension: {config.ndim}')
    print(f'Epoch: {config.train.epoch}')
    print(f'Sample size: {config.train.nsample}')
    print(f'Batch size: {config.train.nbatch}')

# %%
cfg = get_baseconfig()
configurer = get_configuration()

# %%
case = 'VAE'

# %%
cfg_vae = configurer.setup_config(cfg, case)

# %%
check_parameter(cfg_vae)
# Out:
# Case: Latent space of VAE
# Problem: bayes
# Number of steps: 256
# Device: cuda:1
# Number of dimension: 30
# Epoch: 2000
# Sample size: 40000
# Batch size: 2000

# %%
trainer = cfg_vae.train.method

# %%
LFmodel = LF_base(cfg_vae)
LFmodel.to(cfg_vae.device)
# Out:
# LF_base(
#   (flow): NN_Base(
#     (layers): Sequential(
#       (0): Linear(in_features=30, out_features=64, bias=True)
#       (1): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=64, out_features=64, bias=True)
#       )
#       (2): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=64, out_features=64, bias=True)
#       )
#       (3): SiLU()
#       (4): Linear(in_features=64, out_features=30, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Train LFIS

# %%
output = trainer(cfg_vae)
save_file(case, output)
# Out:
# tensor(0.) tensor(0., device='cuda:1')
# time = 0.0000, loss = 0.0000, percetage = nan%
# Complete Training Flow at time 0.0000
# tensor(0.0039) tensor(17.8476, device='cuda:1')
# time = 0.0039, loss = 57.2813, percetage = 99.9503%
# time = 0.0039, loss = 8.7918, percetage = 14.9653%
# time = 0.0039, loss = 2.2000, percetage = 3.6010%
# time = 0.0039, loss = 0.8126, percetage = 1.3853%
# time = 0.0039, loss = 0.5327, percetage = 1.0122%
# time = 0.0039, loss = 0.4390, percetage = 0.7709%
# time = 0.0039, loss = 0.3849, percetage = 0.6245%
# time = 0.0039, loss = 0.2764, percetage = 0.4950%
# time = 0.0039, loss = 0.2512, percetage = 0.4634%
# time = 0.0039, loss = 0.2012, percetage = 0.3934%
# Complete Training Flow at time 0.0039
# tensor(0.0078) tensor(35.2444, device='cuda:1')
# time = 0.0078, loss = 53.3347, percetage = 23.4060%
# time = 0.0078, loss = 1.0012, percetage = 0.4575%
# time = 0.0078, loss = 0.9721, percetage = 0.4399%
# time = 0.0078, loss = 0.8875, percetage = 0.3869%
# time = 0.0078, loss = 0.8590, percetage = 0.3984%
# time = 0.0078, loss = 0.8762, percetage = 0.3878%
# time = 0.0078, loss = 0.7777, percetage = 0.3421%
# time = 0.0078, loss = 0.7359, percetage = 0.3240%
# time = 0.0078, loss = 0.7527, percetage = 0.3276%
# time = 0.0078, loss = 0.7395, percetage = 0.3397%
# ===Reducing LR====
# Complete Training Flow at time 0.0078
# tensor(0.0117) tensor(51.5837, device='cuda:1')
# time = 0.0117, loss = 43.0478, percetage = 9.2256%
# time = 0.0117, loss = 2.1000, percetage = 0.4373%
# time = 0.0117, loss = 2.1833, percetage = 0.4863%
# time = 0.0117, loss = 1.9991, percetage = 0.4420%
# time = 0.0117, loss = 2.0375, percetage = 0.4499%
# ===Reducing LR====
# time = 0.0117, loss = 1.8569, percetage = 0.4080%
# ===Reducing LR====
# time = 0.0117, loss = 1.8351, percetage = 0.3878%
# ===Reducing LR====
# time = 0.0117, loss = 1.8033, percetage = 0.3826%
# ===Reducing LR====
# time = 0.0117, loss = 1.8031, percetage = 0.4009%
# time = 0.0117, loss = 1.7219, percetage = 0.3834%
# ===Reducing LR====
# Complete Training Flow at time 0.0117
# tensor(0.0156) tensor(66.4226, device='cuda:1')
# time = 0.0156, loss = 35.1304, percetage = 4.1933%
# time = 0.0156, loss = 3.9781, percetage = 0.5475%
# time = 0.0156, loss = 4.0688, percetage = 0.5446%
# time = 0.0156, loss = 3.9588, percetage = 0.4676%
# ===Reducing LR====
# time = 0.0156, loss = 3.7994, percetage = 0.4973%
# time = 0.0156, loss = 3.7642, percetage = 0.5164%
# ===Reducing LR====
# time = 0.0156, loss = 3.7214, percetage = 0.5083%
# ===Reducing LR====
# time = 0.0156, loss = 3.5339, percetage = 0.4687%
# time = 0.0156, loss = 3.5651, percetage = 0.4855%
# ===Reducing LR====
# time = 0.0156, loss = 3.5354, percetage = 0.4715%
# ===Reducing LR====
# Complete Training Flow at time 0.0156
# tensor(0.0195) tensor(79.5309, device='cuda:1')
# time = 0.0195, loss = 22.7068, percetage = 2.4317%
# time = 0.0195, loss = 6.7335, percetage = 0.6464%
# time = 0.0195, loss = 6.3795, percetage = 0.6406%
# ===Reducing LR====
# time = 0.0195, loss = 6.0114, percetage = 0.5788%
# time = 0.0195, loss = 6.0588, percetage = 0.5892%
# time = 0.0195, loss = 6.0532, percetage = 0.6244%
# ===Reducing LR====
# time = 0.0195, loss = 6.0024, percetage = 0.6451%
# ===Reducing LR====
# time = 0.0195, loss = 6.2311, percetage = 0.6035%
# ===Reducing LR====
# time = 0.0195, loss = 5.8223, percetage = 0.5865%
# time = 0.0195, loss = 5.6150, percetage = 0.5308%
# ===Reducing LR====
# Complete Training Flow at time 0.0195
# tensor(0.0234) tensor(90.8796, device='cuda:1')
# time = 0.0234, loss = 19.4783, percetage = 1.5526%
# time = 0.0234, loss = 8.6635, percetage = 0.6811%
# time = 0.0234, loss = 9.0995, percetage = 0.7047%
# time = 0.0234, loss = 8.6945, percetage = 0.6778%
# time = 0.0234, loss = 8.7886, percetage = 0.7456%
# time = 0.0234, loss = 8.4217, percetage = 0.6318%
# ===Reducing LR====
# time = 0.0234, loss = 8.3054, percetage = 0.6554%
# time = 0.0234, loss = 8.6922, percetage = 0.7048%
# time = 0.0234, loss = 8.3204, percetage = 0.6551%
# ===Reducing LR====
# time = 0.0234, loss = 8.0908, percetage = 0.6830%
# Complete Training Flow at time 0.0234
# tensor(0.0273) tensor(100.5870, device='cuda:1')
# time = 0.0273, loss = 19.6469, percetage = 1.2940%
# time = 0.0273, loss = 10.9274, percetage = 0.7568%
# ===Reducing LR====
# time = 0.0273, loss = 10.4779, percetage = 0.7600%
# time = 0.0273, loss = 10.7210, percetage = 0.7694%
# time = 0.0273, loss = 10.2018, percetage = 0.7445%
# ===Reducing LR====
# time = 0.0273, loss = 9.7192, percetage = 0.6767%
# ===Reducing LR====
# time = 0.0273, loss = 9.9409, percetage = 0.7338%
# ===Reducing LR====
# time = 0.0273, loss = 9.8580, percetage = 0.6175%
# ===Reducing LR====
# time = 0.0273, loss = 10.4381, percetage = 0.7013%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0273
# tensor(0.0312) tensor(108.8493, device='cuda:1')
# time = 0.0312, loss = 20.0840, percetage = 1.2746%
# time = 0.0312, loss = 13.1178, percetage = 0.8132%
# time = 0.0312, loss = 13.7238, percetage = 0.8540%
# ===Reducing LR====
# time = 0.0312, loss = 12.3899, percetage = 0.7743%
# time = 0.0312, loss = 11.7916, percetage = 0.7136%
# time = 0.0312, loss = 12.0923, percetage = 0.7270%
# ===Reducing LR====
# time = 0.0312, loss = 12.1371, percetage = 0.7626%
# ===Reducing LR====
# time = 0.0312, loss = 11.9124, percetage = 0.7364%
# ===Reducing LR====
# time = 0.0312, loss = 12.0241, percetage = 0.7151%
# ===Reducing LR====
# time = 0.0312, loss = 11.8755, percetage = 0.7197%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0312
# tensor(0.0352) tensor(115.8840, device='cuda:1')
# time = 0.0352, loss = 21.7993, percetage = 1.3601%
# time = 0.0352, loss = 14.3889, percetage = 0.8460%
# ===Reducing LR====
# time = 0.0352, loss = 14.3663, percetage = 0.8944%
# time = 0.0352, loss = 13.8948, percetage = 0.8338%
# time = 0.0352, loss = 13.7507, percetage = 0.7730%
# ===Reducing LR====
# time = 0.0352, loss = 13.7206, percetage = 0.8079%
# ===Reducing LR====
# time = 0.0352, loss = 14.2105, percetage = 0.8423%
# ===Reducing LR====
# time = 0.0352, loss = 13.4644, percetage = 0.8127%
# ===Reducing LR====
# time = 0.0352, loss = 13.7018, percetage = 0.8701%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0352
# tensor(0.0391) tensor(121.8872, device='cuda:1')
# time = 0.0391, loss = 22.5240, percetage = 1.2127%
# time = 0.0391, loss = 15.9718, percetage = 0.9054%
# ===Reducing LR====
# time = 0.0391, loss = 14.7874, percetage = 0.8398%
# ===Reducing LR====
# time = 0.0391, loss = 15.5051, percetage = 0.9418%
# time = 0.0391, loss = 14.5548, percetage = 0.8323%
# ===Reducing LR====
# time = 0.0391, loss = 15.0253, percetage = 0.8677%
# time = 0.0391, loss = 14.2363, percetage = 0.9033%
# ===Reducing LR====
# time = 0.0391, loss = 14.1597, percetage = 0.8238%
# ===Reducing LR====
# time = 0.0391, loss = 15.0848, percetage = 0.8554%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0391
# tensor(0.0430) tensor(127.0276, device='cuda:1')
# time = 0.0430, loss = 22.3547, percetage = 1.2452%
# time = 0.0430, loss = 16.6156, percetage = 0.9940%
# time = 0.0430, loss = 17.1747, percetage = 0.9520%
# ===Reducing LR====
# time = 0.0430, loss = 15.8998, percetage = 0.9063%
# ===Reducing LR====
# time = 0.0430, loss = 14.4563, percetage = 0.8698%
# time = 0.0430, loss = 15.3856, percetage = 0.9292%
# ===Reducing LR====
# time = 0.0430, loss = 15.0028, percetage = 0.8602%
# ===Reducing LR====
# time = 0.0430, loss = 15.7067, percetage = 0.9331%
# time = 0.0430, loss = 14.8463, percetage = 0.8080%
# ===Reducing LR====
# time = 0.0430, loss = 14.6501, percetage = 0.8014%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0430
# tensor(0.0469) tensor(131.4408, device='cuda:1')
# time = 0.0469, loss = 22.6793, percetage = 1.2842%
# time = 0.0469, loss = 18.2475, percetage = 0.9637%
# time = 0.0469, loss = 18.1720, percetage = 1.0569%
# ===Reducing LR====
# time = 0.0469, loss = 17.3371, percetage = 0.9381%
# time = 0.0469, loss = 17.0506, percetage = 0.9341%
# ===Reducing LR====
# time = 0.0469, loss = 16.1623, percetage = 0.8868%
# ===Reducing LR====
# time = 0.0469, loss = 16.0915, percetage = 0.9058%
# ===Reducing LR====
# time = 0.0469, loss = 16.5577, percetage = 0.9190%
# ===Reducing LR====
# time = 0.0469, loss = 15.9649, percetage = 0.8574%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0469
# tensor(0.0508) tensor(135.2306, device='cuda:1')
# time = 0.0508, loss = 22.4933, percetage = 1.3232%
# time = 0.0508, loss = 17.0637, percetage = 1.0035%
# ===Reducing LR====
# time = 0.0508, loss = 19.2875, percetage = 1.0720%
# time = 0.0508, loss = 16.9114, percetage = 0.9592%
# ===Reducing LR====
# time = 0.0508, loss = 17.8052, percetage = 0.9451%
# ===Reducing LR====
# time = 0.0508, loss = 16.9125, percetage = 0.9445%
# time = 0.0508, loss = 17.2286, percetage = 1.0179%
# time = 0.0508, loss = 16.6904, percetage = 0.9249%
# ===Reducing LR====
# time = 0.0508, loss = 17.2157, percetage = 1.0390%
# ===Reducing LR====
# time = 0.0508, loss = 16.9553, percetage = 0.9163%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0508
# tensor(0.0547) tensor(138.4780, device='cuda:1')
# time = 0.0547, loss = 23.9121, percetage = 1.3944%
# time = 0.0547, loss = 18.6921, percetage = 0.9601%
# ===Reducing LR====
# time = 0.0547, loss = 18.2679, percetage = 1.1171%
# ===Reducing LR====
# time = 0.0547, loss = 18.5191, percetage = 1.0117%
# ===Reducing LR====
# time = 0.0547, loss = 17.6064, percetage = 0.9465%
# time = 0.0547, loss = 16.1878, percetage = 0.8717%
# time = 0.0547, loss = 19.0432, percetage = 1.0580%
# ===Reducing LR====
# time = 0.0547, loss = 17.9494, percetage = 0.8922%
# ===Reducing LR====
# time = 0.0547, loss = 16.9277, percetage = 0.9104%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0547
# tensor(0.0586) tensor(141.2493, device='cuda:1')
# time = 0.0586, loss = 23.6219, percetage = 1.3750%
# time = 0.0586, loss = 18.5039, percetage = 1.0399%
# time = 0.0586, loss = 20.3110, percetage = 1.2004%
# ===Reducing LR====
# time = 0.0586, loss = 18.7646, percetage = 0.9983%
# time = 0.0586, loss = 20.9198, percetage = 1.2195%
# ===Reducing LR====
# time = 0.0586, loss = 18.9820, percetage = 1.1336%
# ===Reducing LR====
# time = 0.0586, loss = 18.5457, percetage = 1.0933%
# ===Reducing LR====
# time = 0.0586, loss = 16.9388, percetage = 0.9501%
# time = 0.0586, loss = 17.7760, percetage = 1.1077%
# time = 0.0586, loss = 17.8343, percetage = 1.1207%
# ===Reducing LR====
# Complete Training Flow at time 0.0586
# tensor(0.0625) tensor(143.5996, device='cuda:1')
# time = 0.0625, loss = 24.0012, percetage = 1.4301%
# time = 0.0625, loss = 19.4204, percetage = 1.2428%
# ===Reducing LR====
# time = 0.0625, loss = 19.1336, percetage = 1.1862%
# time = 0.0625, loss = 19.8350, percetage = 1.1835%
# time = 0.0625, loss = 19.3401, percetage = 1.0305%
# time = 0.0625, loss = 19.8243, percetage = 1.1823%
# ===Reducing LR====
# time = 0.0625, loss = 19.3443, percetage = 1.0802%
# ===Reducing LR====
# time = 0.0625, loss = 19.9687, percetage = 1.1266%
# ===Reducing LR====
# time = 0.0625, loss = 19.5596, percetage = 1.1215%
# ===Reducing LR====
# time = 0.0625, loss = 19.2473, percetage = 1.1204%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0625
# tensor(0.0664) tensor(145.5740, device='cuda:1')
# time = 0.0664, loss = 24.2969, percetage = 1.4030%
# time = 0.0664, loss = 22.0940, percetage = 1.2707%
# ===Reducing LR====
# time = 0.0664, loss = 21.9861, percetage = 1.2837%
# time = 0.0664, loss = 20.0563, percetage = 1.1706%
# time = 0.0664, loss = 20.5554, percetage = 1.1416%
# time = 0.0664, loss = 21.4077, percetage = 1.2879%
# ===Reducing LR====
# time = 0.0664, loss = 19.8852, percetage = 1.1136%
# time = 0.0664, loss = 19.5813, percetage = 1.1041%
# time = 0.0664, loss = 20.3285, percetage = 1.2520%
# time = 0.0664, loss = 19.8324, percetage = 1.1056%
# ===Reducing LR====
# Complete Training Flow at time 0.0664
# tensor(0.0703) tensor(147.2104, device='cuda:1')
# time = 0.0703, loss = 24.3022, percetage = 1.4527%
# time = 0.0703, loss = 21.7771, percetage = 1.3525%
# time = 0.0703, loss = 22.7507, percetage = 1.2864%
# time = 0.0703, loss = 22.5362, percetage = 1.2638%
# ===Reducing LR====
# time = 0.0703, loss = 21.7422, percetage = 1.3810%
# time = 0.0703, loss = 20.7262, percetage = 1.2877%
# ===Reducing LR====
# time = 0.0703, loss = 20.5606, percetage = 1.1865%
# time = 0.0703, loss = 20.3965, percetage = 1.2237%
# time = 0.0703, loss = 20.2679, percetage = 1.2342%
# ===Reducing LR====
# time = 0.0703, loss = 21.2062, percetage = 1.1803%
# ===Reducing LR====
# Complete Training Flow at time 0.0703
# tensor(0.0742) tensor(148.5448, device='cuda:1')
# time = 0.0742, loss = 25.2191, percetage = 1.5026%
# time = 0.0742, loss = 22.7783, percetage = 1.3333%
# ===Reducing LR====
# time = 0.0742, loss = 21.1375, percetage = 1.2061%
# time = 0.0742, loss = 21.8355, percetage = 1.2478%
# time = 0.0742, loss = 21.6871, percetage = 1.2802%
# ===Reducing LR====
# time = 0.0742, loss = 22.7766, percetage = 1.3080%
# ===Reducing LR====
# time = 0.0742, loss = 22.7693, percetage = 1.3931%
# ===Reducing LR====
# time = 0.0742, loss = 22.7384, percetage = 1.3447%
# time = 0.0742, loss = 21.6905, percetage = 1.2932%
# ===Reducing LR====
# time = 0.0742, loss = 20.9190, percetage = 1.2570%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0742
# tensor(0.0781) tensor(149.6026, device='cuda:1')
# time = 0.0781, loss = 26.2479, percetage = 1.5267%
# time = 0.0781, loss = 23.1899, percetage = 1.3851%
# time = 0.0781, loss = 23.9628, percetage = 1.4116%
# ===Reducing LR====
# time = 0.0781, loss = 22.3501, percetage = 1.3509%
# time = 0.0781, loss = 24.2087, percetage = 1.4795%
# time = 0.0781, loss = 22.2433, percetage = 1.4234%
# ===Reducing LR====
# time = 0.0781, loss = 21.3468, percetage = 1.4274%
# ===Reducing LR====
# time = 0.0781, loss = 20.5998, percetage = 1.2999%
# ===Reducing LR====
# time = 0.0781, loss = 21.2047, percetage = 1.3248%
# ===Reducing LR====
# time = 0.0781, loss = 21.5851, percetage = 1.2842%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0781
# tensor(0.0820) tensor(150.4140, device='cuda:1')
# time = 0.0820, loss = 24.9800, percetage = 1.5398%
# time = 0.0820, loss = 24.5238, percetage = 1.4812%
# ===Reducing LR====
# time = 0.0820, loss = 24.3334, percetage = 1.5023%
# ===Reducing LR====
# time = 0.0820, loss = 23.4792, percetage = 1.5433%
# time = 0.0820, loss = 24.7439, percetage = 1.5068%
# ===Reducing LR====
# time = 0.0820, loss = 23.2665, percetage = 1.4601%
# ===Reducing LR====
# time = 0.0820, loss = 23.2470, percetage = 1.4594%
# ===Reducing LR====
# time = 0.0820, loss = 23.3152, percetage = 1.5665%
# time = 0.0820, loss = 22.6257, percetage = 1.4464%
# time = 0.0820, loss = 21.6367, percetage = 1.2615%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0820
# tensor(0.0859) tensor(151.0042, device='cuda:1')
# time = 0.0859, loss = 27.4850, percetage = 1.6444%
# time = 0.0859, loss = 23.0785, percetage = 1.4582%
# time = 0.0859, loss = 25.7876, percetage = 1.5905%
# ===Reducing LR====
# time = 0.0859, loss = 24.0384, percetage = 1.5106%
# time = 0.0859, loss = 24.8280, percetage = 1.5918%
# ===Reducing LR====
# time = 0.0859, loss = 23.8048, percetage = 1.5112%
# ===Reducing LR====
# time = 0.0859, loss = 23.7876, percetage = 1.4088%
# time = 0.0859, loss = 25.1059, percetage = 1.6641%
# ===Reducing LR====
# time = 0.0859, loss = 23.4324, percetage = 1.4229%
# ===Reducing LR====
# time = 0.0859, loss = 23.7647, percetage = 1.4831%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0859
# tensor(0.0898) tensor(151.3988, device='cuda:1')
# time = 0.0898, loss = 27.9675, percetage = 1.7588%
# time = 0.0898, loss = 27.5841, percetage = 1.7667%
# time = 0.0898, loss = 28.0258, percetage = 1.8073%
# ===Reducing LR====
# time = 0.0898, loss = 24.4552, percetage = 1.5312%
# ===Reducing LR====
# time = 0.0898, loss = 24.2705, percetage = 1.4508%
# time = 0.0898, loss = 23.8212, percetage = 1.4974%
# ===Reducing LR====
# time = 0.0898, loss = 24.4603, percetage = 1.5155%
# ===Reducing LR====
# time = 0.0898, loss = 24.3263, percetage = 1.5979%
# ===Reducing LR====
# time = 0.0898, loss = 24.4858, percetage = 1.4989%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0898
# tensor(0.0938) tensor(151.6234, device='cuda:1')
# time = 0.0938, loss = 27.9100, percetage = 1.7822%
# time = 0.0938, loss = 28.6403, percetage = 1.8187%
# ===Reducing LR====
# time = 0.0938, loss = 25.7712, percetage = 1.6435%
# ===Reducing LR====
# time = 0.0938, loss = 24.5696, percetage = 1.6399%
# time = 0.0938, loss = 27.0344, percetage = 1.5842%
# time = 0.0938, loss = 24.7735, percetage = 1.6357%
# ===Reducing LR====
# time = 0.0938, loss = 24.2831, percetage = 1.6010%
# ===Reducing LR====
# time = 0.0938, loss = 25.6356, percetage = 1.5553%
# time = 0.0938, loss = 24.1794, percetage = 1.5772%
# ===Reducing LR====
# time = 0.0938, loss = 24.6932, percetage = 1.6327%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0938
# tensor(0.0977) tensor(151.7009, device='cuda:1')
# time = 0.0977, loss = 28.8519, percetage = 1.8121%
# time = 0.0977, loss = 26.3650, percetage = 1.7621%
# ===Reducing LR====
# time = 0.0977, loss = 24.8415, percetage = 1.5307%
# time = 0.0977, loss = 24.5747, percetage = 1.5763%
# ===Reducing LR====
# time = 0.0977, loss = 25.7674, percetage = 1.7803%
# ===Reducing LR====
# time = 0.0977, loss = 24.5747, percetage = 1.6789%
# time = 0.0977, loss = 25.5530, percetage = 1.6798%
# ===Reducing LR====
# time = 0.0977, loss = 25.6793, percetage = 1.6316%
# ===Reducing LR====
# time = 0.0977, loss = 25.1884, percetage = 1.6784%
# time = 0.0977, loss = 24.0107, percetage = 1.5057%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.0977
# tensor(0.1016) tensor(151.6530, device='cuda:1')
# time = 0.1016, loss = 27.6595, percetage = 1.7293%
# time = 0.1016, loss = 28.2810, percetage = 1.8660%
# ===Reducing LR====
# time = 0.1016, loss = 26.2831, percetage = 1.6998%
# time = 0.1016, loss = 27.5807, percetage = 1.7527%
# time = 0.1016, loss = 24.5693, percetage = 1.7311%
# ===Reducing LR====
# time = 0.1016, loss = 24.4301, percetage = 1.6087%
# time = 0.1016, loss = 25.5457, percetage = 1.6879%
# ===Reducing LR====
# time = 0.1016, loss = 27.3567, percetage = 1.6984%
# time = 0.1016, loss = 26.0348, percetage = 1.7427%
# ===Reducing LR====
# time = 0.1016, loss = 25.1305, percetage = 1.7263%
# ===Reducing LR====
# Complete Training Flow at time 0.1016
# tensor(0.1055) tensor(151.5017, device='cuda:1')
# time = 0.1055, loss = 26.4528, percetage = 1.8516%
# time = 0.1055, loss = 26.4168, percetage = 1.8723%
# time = 0.1055, loss = 25.8597, percetage = 1.8155%
# ===Reducing LR====
# time = 0.1055, loss = 26.0967, percetage = 1.8352%
# time = 0.1055, loss = 25.9094, percetage = 1.7918%
# ===Reducing LR====
# time = 0.1055, loss = 23.9149, percetage = 1.7574%
# ===Reducing LR====
# time = 0.1055, loss = 24.6100, percetage = 1.7329%
# ===Reducing LR====
# time = 0.1055, loss = 25.1077, percetage = 1.6160%
# ===Reducing LR====
# time = 0.1055, loss = 24.0490, percetage = 1.5958%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1055
# tensor(0.1094) tensor(151.2666, device='cuda:1')
# time = 0.1094, loss = 29.8033, percetage = 2.0038%
# time = 0.1094, loss = 25.5424, percetage = 1.8925%
# ===Reducing LR====
# time = 0.1094, loss = 23.6652, percetage = 1.7682%
# ===Reducing LR====
# time = 0.1094, loss = 26.0071, percetage = 1.7935%
# ===Reducing LR====
# time = 0.1094, loss = 27.6147, percetage = 1.9430%
# ===Reducing LR====
# time = 0.1094, loss = 24.1446, percetage = 1.6386%
# time = 0.1094, loss = 25.4855, percetage = 1.8073%
# ===Reducing LR====
# time = 0.1094, loss = 25.1903, percetage = 1.7302%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1094
# tensor(0.1133) tensor(150.9646, device='cuda:1')
# time = 0.1133, loss = 26.4372, percetage = 1.9717%
# time = 0.1133, loss = 25.3455, percetage = 1.9337%
# ===Reducing LR====
# time = 0.1133, loss = 23.5027, percetage = 1.7424%
# time = 0.1133, loss = 23.8572, percetage = 1.7504%
# ===Reducing LR====
# time = 0.1133, loss = 24.4645, percetage = 1.8195%
# ===Reducing LR====
# time = 0.1133, loss = 25.5470, percetage = 1.8563%
# ===Reducing LR====
# time = 0.1133, loss = 25.2516, percetage = 1.7157%
# ===Reducing LR====
# time = 0.1133, loss = 24.7811, percetage = 1.7780%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1133
# tensor(0.1172) tensor(150.6085, device='cuda:1')
# time = 0.1172, loss = 26.7701, percetage = 2.0633%
# time = 0.1172, loss = 26.4039, percetage = 1.8388%
# time = 0.1172, loss = 28.2332, percetage = 2.1349%
# ===Reducing LR====
# time = 0.1172, loss = 25.2809, percetage = 1.8116%
# time = 0.1172, loss = 25.0435, percetage = 1.8259%
# ===Reducing LR====
# time = 0.1172, loss = 24.7703, percetage = 1.8202%
# ===Reducing LR====
# time = 0.1172, loss = 25.5462, percetage = 1.8623%
# ===Reducing LR====
# time = 0.1172, loss = 24.3153, percetage = 1.7950%
# ===Reducing LR====
# time = 0.1172, loss = 24.7237, percetage = 1.7888%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1172
# tensor(0.1211) tensor(150.2207, device='cuda:1')
# time = 0.1211, loss = 26.0886, percetage = 2.0029%
# time = 0.1211, loss = 25.7569, percetage = 2.1008%
# ===Reducing LR====
# time = 0.1211, loss = 24.8839, percetage = 1.9696%
# ===Reducing LR====
# time = 0.1211, loss = 23.3220, percetage = 1.7667%
# ===Reducing LR====
# time = 0.1211, loss = 23.5223, percetage = 1.8941%
# ===Reducing LR====
# time = 0.1211, loss = 24.4886, percetage = 1.8047%
# ===Reducing LR====
# time = 0.1211, loss = 22.8120, percetage = 1.7785%
# time = 0.1211, loss = 24.6039, percetage = 1.9826%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1211
# tensor(0.1250) tensor(149.8108, device='cuda:1')
# time = 0.1250, loss = 27.5459, percetage = 2.1253%
# time = 0.1250, loss = 26.6982, percetage = 1.9436%
# ===Reducing LR====
# time = 0.1250, loss = 24.7186, percetage = 1.8228%
# time = 0.1250, loss = 24.7061, percetage = 2.0049%
# ===Reducing LR====
# time = 0.1250, loss = 23.4166, percetage = 1.8289%
# time = 0.1250, loss = 25.4843, percetage = 2.0172%
# ===Reducing LR====
# time = 0.1250, loss = 24.0717, percetage = 1.8974%
# ===Reducing LR====
# time = 0.1250, loss = 23.5173, percetage = 1.8971%
# time = 0.1250, loss = 25.0325, percetage = 2.0236%
# ===Reducing LR====
# time = 0.1250, loss = 23.6980, percetage = 1.8454%
# Complete Training Flow at time 0.1250
# tensor(0.1289) tensor(149.3881, device='cuda:1')
# time = 0.1289, loss = 26.4285, percetage = 2.1752%
# time = 0.1289, loss = 25.1614, percetage = 2.1278%
# ===Reducing LR====
# time = 0.1289, loss = 22.8523, percetage = 1.8192%
# time = 0.1289, loss = 23.1811, percetage = 1.8169%
# ===Reducing LR====
# time = 0.1289, loss = 20.8891, percetage = 1.7616%
# ===Reducing LR====
# time = 0.1289, loss = 24.0485, percetage = 1.8433%
# ===Reducing LR====
# time = 0.1289, loss = 23.5532, percetage = 2.0335%
# ===Reducing LR====
# time = 0.1289, loss = 22.8119, percetage = 1.9997%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1289
# tensor(0.1328) tensor(148.9648, device='cuda:1')
# time = 0.1328, loss = 24.5551, percetage = 2.0732%
# time = 0.1328, loss = 24.8146, percetage = 2.1499%
# time = 0.1328, loss = 24.0149, percetage = 2.0573%
# ===Reducing LR====
# time = 0.1328, loss = 22.4421, percetage = 1.8389%
# time = 0.1328, loss = 23.1441, percetage = 1.8811%
# ===Reducing LR====
# time = 0.1328, loss = 22.5820, percetage = 1.8677%
# ===Reducing LR====
# time = 0.1328, loss = 21.4772, percetage = 1.8209%
# ===Reducing LR====
# time = 0.1328, loss = 22.0200, percetage = 1.8235%
# ===Reducing LR====
# time = 0.1328, loss = 23.7017, percetage = 1.9356%
# time = 0.1328, loss = 22.3995, percetage = 1.7279%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1328
# tensor(0.1367) tensor(148.5471, device='cuda:1')
# time = 0.1367, loss = 22.7435, percetage = 1.9851%
# time = 0.1367, loss = 22.0524, percetage = 1.9050%
# time = 0.1367, loss = 24.0084, percetage = 1.9662%
# ===Reducing LR====
# time = 0.1367, loss = 22.7138, percetage = 1.8915%
# ===Reducing LR====
# time = 0.1367, loss = 22.1494, percetage = 1.8685%
# ===Reducing LR====
# time = 0.1367, loss = 19.8346, percetage = 1.7085%
# ===Reducing LR====
# time = 0.1367, loss = 21.7008, percetage = 1.8542%
# ===Reducing LR====
# time = 0.1367, loss = 23.2953, percetage = 2.0081%
# time = 0.1367, loss = 24.8602, percetage = 1.9247%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1367
# tensor(0.1406) tensor(148.1416, device='cuda:1')
# time = 0.1406, loss = 22.3607, percetage = 1.9535%
# time = 0.1406, loss = 23.3181, percetage = 1.9805%
# ===Reducing LR====
# time = 0.1406, loss = 20.7251, percetage = 1.8580%
# ===Reducing LR====
# time = 0.1406, loss = 21.4234, percetage = 1.8733%
# time = 0.1406, loss = 22.5545, percetage = 2.0711%
# time = 0.1406, loss = 20.4321, percetage = 1.8326%
# time = 0.1406, loss = 19.8587, percetage = 1.7955%
# ===Reducing LR====
# time = 0.1406, loss = 20.8183, percetage = 1.8931%
# ===Reducing LR====
# time = 0.1406, loss = 20.2471, percetage = 1.8313%
# ===Reducing LR====
# time = 0.1406, loss = 23.6840, percetage = 2.0500%
# Complete Training Flow at time 0.1406
# tensor(0.1445) tensor(147.7521, device='cuda:1')
# time = 0.1445, loss = 22.2320, percetage = 2.0497%
# time = 0.1445, loss = 20.7825, percetage = 1.8674%
# ===Reducing LR====
# time = 0.1445, loss = 22.5180, percetage = 2.0520%
# ===Reducing LR====
# time = 0.1445, loss = 20.7544, percetage = 1.8589%
# ===Reducing LR====
# time = 0.1445, loss = 20.7920, percetage = 1.9277%
# time = 0.1445, loss = 21.0290, percetage = 2.0154%
# ===Reducing LR====
# time = 0.1445, loss = 19.8306, percetage = 1.8193%
# ===Reducing LR====
# time = 0.1445, loss = 20.9260, percetage = 1.9208%
# time = 0.1445, loss = 21.2160, percetage = 1.8985%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1445
# tensor(0.1484) tensor(147.3816, device='cuda:1')
# time = 0.1484, loss = 20.9583, percetage = 2.0173%
# time = 0.1484, loss = 20.8486, percetage = 1.9418%
# time = 0.1484, loss = 21.4313, percetage = 1.8835%
# ===Reducing LR====
# time = 0.1484, loss = 19.5373, percetage = 1.8524%
# time = 0.1484, loss = 20.5348, percetage = 1.9773%
# ===Reducing LR====
# time = 0.1484, loss = 20.5898, percetage = 1.9853%
# ===Reducing LR====
# time = 0.1484, loss = 20.6215, percetage = 2.0043%
# ===Reducing LR====
# time = 0.1484, loss = 19.6952, percetage = 1.9407%
# ===Reducing LR====
# time = 0.1484, loss = 18.3998, percetage = 1.7004%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1484
# tensor(0.1523) tensor(147.0321, device='cuda:1')
# time = 0.1523, loss = 19.3965, percetage = 1.9250%
# time = 0.1523, loss = 19.7755, percetage = 2.0081%
# ===Reducing LR====
# time = 0.1523, loss = 19.0394, percetage = 1.9998%
# ===Reducing LR====
# time = 0.1523, loss = 18.5879, percetage = 1.7724%
# time = 0.1523, loss = 19.8827, percetage = 2.0385%
# time = 0.1523, loss = 19.3206, percetage = 1.8030%
# ===Reducing LR====
# time = 0.1523, loss = 18.6607, percetage = 1.7771%
# time = 0.1523, loss = 18.7967, percetage = 1.8582%
# ===Reducing LR====
# time = 0.1523, loss = 19.1613, percetage = 1.8181%
# ===Reducing LR====
# time = 0.1523, loss = 17.8372, percetage = 1.7123%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1523
# tensor(0.1562) tensor(146.7064, device='cuda:1')
# time = 0.1562, loss = 19.5891, percetage = 1.9538%
# time = 0.1562, loss = 20.1262, percetage = 2.0611%
# time = 0.1562, loss = 21.4454, percetage = 2.1136%
# ===Reducing LR====
# time = 0.1562, loss = 18.5399, percetage = 1.8610%
# ===Reducing LR====
# time = 0.1562, loss = 17.6446, percetage = 1.8623%
# time = 0.1562, loss = 19.7229, percetage = 1.9866%
# ===Reducing LR====
# time = 0.1562, loss = 19.3988, percetage = 1.9942%
# ===Reducing LR====
# time = 0.1562, loss = 16.7097, percetage = 1.7720%
# ===Reducing LR====
# time = 0.1562, loss = 17.7185, percetage = 1.9249%
# time = 0.1562, loss = 16.3454, percetage = 1.7318%
# ===Reducing LR====
# ====LR too small, stop traning ====
# Complete Training Flow at time 0.1562
# tensor(0.1602) tensor(146.4048, device='cuda:1')
# time = 0.1602, loss = 18.2924, percetage = 1.9468%
# time = 0.1602, loss = 18.8722, percetage = 1.8961%
# ===Reducing LR====
# time = 0.1602, loss = 18.0437, percetage = 1.9015%
# time = 0.1602, loss = 19.0221, percetage = 1.8525%
# time = 0.1602, loss = 16.7714, percetage = 1.7022%
# ===Reducing LR====
# time = 0.1602, loss = 18.2945, percetage = 2.1296%
# ===Reducing LR====
# time = 0.1602, loss = 17.1680, percetage = 1.9901%
# time = 0.1602, loss = 17.1081, percetage = 1.8137%
# time = 0.1602, loss = 17.2375, percetage = 1.8450%
# ===Reducing LR====
# time = 0.1602, loss = 18.3166, percetage = 1.8250%
# ===Reducing LR====
# Complete Training Flow at time 0.1602
# tensor(0.1641) tensor(146.1295, device='cuda:1')
# time = 0.1641, loss = 17.5213, percetage = 1.8338%
# time = 0.1641, loss = 17.9764, percetage = 2.0674%
# ===Reducing LR====
# time = 0.1641, loss = 18.1942, percetage = 1.9761%
# ===Reducing LR====
# time = 0.1641, loss = 16.6569, percetage = 1.7671%
# time = 0.1641, loss = 14.4881, percetage = 1.6884%
# time = 0.1641, loss = 17.6913, percetage = 1.8272%
# ===Reducing LR====
# time = 0.1641, loss = 16.7281, percetage = 1.8162%
# ===Reducing LR====

# %%
cfg_vae.device

# %% [markdown]
# # Load pre-trained LFIS

# %%
nnmodel = cfg_vae.nnmodel.to(cfg_vae.device)
output = load_file(case, nnmodel)

# %%
logstat = run_stat(LFmodel, output)

# %%
logstat
# Out:
# {'logzmean': -109.96903,
#  'logzstd': 0.012366372,
#  'samples': array([[ 0.0684285 , -1.4232967 , -0.25237828, ...,  0.4447706 ,
#          -1.6089454 ,  1.1831527 ],
#         [-0.17351209, -1.4534276 ,  0.47293678, ...,  0.7649424 ,
#          -0.72959876,  1.4849737 ],
#         [-0.29809332, -0.9174748 ,  1.2713807 , ...,  0.8207334 ,
#           0.05856221, -0.14467365],
#         ...,
#         [ 0.05134677, -0.74020624, -0.37029836, ...,  1.6026207 ,
#          -2.154448  ,  1.1989334 ],
#         [-0.67029727,  0.27515835,  1.614973  , ...,  0.34914234,
#          -0.3009104 ,  0.34380823],
#         [-0.9465235 , -1.1558543 ,  0.2671955 , ..., -0.00423259,
#          -2.5489979 , -0.46416163]], dtype=float32),
#  'weight': array([0.4081321 , 0.7590214 , 1.3564603 , ..., 1.1272177 , 0.69707245,
#         0.41628993], dtype=float32),
#  'logzlist': array([-109.987274, -109.95551 , -109.97655 , -109.95968 , -109.94933 ,
#         -109.95772 , -109.972084, -109.97017 , -109.95672 , -109.958755,
#         -109.987785, -109.98461 , -109.97275 , -109.96257 , -109.97261 ,
#         -109.96696 , -109.979   , -109.96217 , -109.954544, -109.96612 ,
#         -109.96498 , -109.96624 , -109.947044, -109.96536 , -109.9665  ,
#         -109.99255 , -109.96356 , -109.97834 , -109.97466 , -109.99876 ],
#        dtype=float32)}
